# %% [markdown]
# # La vera domanda è: se miglioro l'accuracy miglioro il risultato? prima di fare  la simulazione prendere un periodo in cui si lascia evolvere il sistema

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.rcParams.update({'font.size': 18})

df = pd.read_csv("first.txt")
df2 = pd.read_csv("first2.txt")
points = pd.read_csv("second.txt")
points2 = pd.read_csv("third.txt")
sums = pd.read_csv("sums.txt")


#sns.histplot(df["mean"])
x = np.linspace(1,100,len(df["mean"]))
#sns.histplot(df["mean_2"])

len(df)
# Out:
# 100

# %%
plt.title("Valore medio progressivo di r per $\psi_{1,0,0}$")
plt.axhline(1.5,color='g')
plt.errorbar(x,df['mean'],yerr=df["err"],ecolor='r')
plt.xlabel("Blocchi")
plt.ylabel("$<r>/a_0$")
plt.show()

# %%
plt.title("Valore medio r per $\psi_{2,1,0}$")
plt.axhline(5,color='g')
plt.errorbar(x,df2["mean"],yerr=df2["err"],ecolor='r')
plt.xlabel("Blocchi")
plt.ylabel("$<r>/a_0$")
# Out:
# /home/riccardomartelli/.local/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1174: RuntimeWarning: All-NaN axis encountered
#   miny = np.nanmin(masked_verts[..., 1])
# /home/riccardomartelli/.local/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1175: RuntimeWarning: All-NaN axis encountered
#   maxy = np.nanmax(masked_verts[..., 1])
# Text(0, 0.5, '$<r>/a_0$')

# %%
"""x = points["x"]
y = points["y"]
z = points["z"]

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.set_title("Distribuzione $\psi_{1,0,0}$")
ax.scatter(x, y, z, c=z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(10, 55)"""
# Out:
# 'x = points["x"]\ny = points["y"]\nz = points["z"]\n\nfig = plt.figure()\nax = fig.add_subplot(projection=\'3d\')\nax.set_title("Distribuzione $\\psi_{1,0,0}$")\nax.scatter(x, y, z, c=z, marker=\'.\')\nax.set_xlabel(\'x\')\nax.set_ylabel(\'y\')\nax.set_zlabel(\'z\')\nax.view_init(10, 55)'

# %%
"""x = points2["x"]
y = points2["y"]
z = points2["z"]

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.set_title("Distribuzione $\psi_{2,1,0}$")
ax.scatter(x, y, z, c=z, marker='.')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(0, 55)"""
# Out:
# 'x = points2["x"]\ny = points2["y"]\nz = points2["z"]\n\nfig = plt.figure()\nax = fig.add_subplot(projection=\'3d\')\nax.set_title("Distribuzione $\\psi_{2,1,0}$")\nax.scatter(x, y, z, c=z, marker=\'.\')\nax.set_xlabel(\'x\')\nax.set_ylabel(\'y\')\nax.set_zlabel(\'z\')\nax.view_init(0, 55)'
