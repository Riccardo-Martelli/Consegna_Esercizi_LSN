# %% [markdown]
# Quindi ios::app seve per fare un append essenzialemnente si può usare per campiare i valori in input.in e poi avere le tre simulazioni in un file ora le prime 40 sono fluido, le seconde 40 solido e le ultime 40 gas

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.rcParams.update({'font.size': 20})

pres = pd.read_csv("./MD_MC/MDNVE_MCNVT/output_press.dat",header = None)
epot = pd.read_csv("./MD_MC/MDNVE_MCNVT/output_epot.dat",header = None)
ekin = pd.read_csv("./MD_MC/MDNVE_MCNVT/output_ekin.dat",header = None)
etot = pd.read_csv("./MD_MC/MDNVE_MCNVT/output_etot.dat",header = None)
temp = pd.read_csv("./MD_MC/MDNVE_MCNVT/output_temp.dat",header = None)
equil_temp = pd.read_csv("./MD_MC/MDNVE_MCNVT/temp_equilibration.dat",header = None)

x = np.arange(len(pres[1]))
x=x[:60]

y=np.arange(len(equil_temp)/3)
N= 30000

# %% [markdown]
# # Come stabilzzare T
# Possimo vedere come la temperatura target sia sbagliata e bisogna aggiustarla, dopo varie iterazione si ottengono i seguenti risultati ricalibrati

# %%
plt.figure(figsize=(18,12))

plt.suptitle("Equilibration time for the three states",fontsize=26,fontweight='bold')

plt.subplot(311)
plt.title("Gas",fontweight='bold')
plt.axhline(1.2,color='r',label="$T^* GAS$")
plt.plot(y,equil_temp[:N],label="Temperatura")
plt.xlabel("steps")
plt.ylabel("T")
plt.legend()

plt.subplot(312)
plt.title("Liquid",fontweight='bold')
plt.axhline(1.1,color='r',label="$T^* LIQUIDO$")
plt.plot(y,equil_temp[N:2*N],label="Temperatura")
plt.xlabel("steps")
plt.ylabel("T")
plt.legend()

plt.subplot(313)
plt.title("Solid",fontweight='bold')
plt.axhline(0.8,color='r',label="$T^* SOLIDO$")
plt.plot(y,equil_temp[2*N:3*N],label="Temperatura")
plt.xlabel("steps")
plt.ylabel("T")
plt.legend()

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Grafici Gas

# %%
plt.figure(figsize=(20,12))

plt.suptitle("GAS",fontsize=26,fontweight='bold')

plt.subplot(2,3,1)
plt.title("Pressione",fontweight='bold')
plt.errorbar(x,pres[1][:60],yerr=pres[3][:60],ecolor='r')
plt.xlabel("Blocks")
plt.ylabel("Pressione")
plt.grid(True)

plt.subplot(2,3,2)
plt.title("Temperatura",fontweight='bold')
plt.errorbar(x,temp[1][:60],yerr=temp[3][:60],ecolor='r')
plt.axhline(1.2,color='g',label="$T^*$")
plt.xlabel("Blocks")
plt.ylabel("$T^*$")
plt.legend()
plt.grid(True)

plt.subplot(2,3,3)
plt.title("Energia potenziale",fontweight='bold')
plt.errorbar(x,epot[1][:60],yerr=epot[3][:60],ecolor='r')
plt.xlabel("Blocks")
plt.ylabel("$U^*/N$")
plt.grid(True)

plt.subplot(2,3,4)
plt.title("Energia cinetica",fontweight='bold')
plt.errorbar(x,ekin[1][:60],yerr=ekin[3][:60],ecolor='r')
plt.xlabel("Blocks")
plt.ylabel("$K^*/N$")
plt.grid(True)

plt.subplot(2,3,5)
plt.title("Energia totale",fontweight='bold')
plt.errorbar(x,etot[1][:60],yerr=etot[3][:60],ecolor='r')
plt.xlabel("Blocks")
plt.ylabel("$E^*/N$")
plt.grid(True)

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Grafici liquido

# %%
plt.figure(figsize=(20,12))

plt.suptitle("LIQUIDO",fontsize=26,fontweight='bold')

plt.subplot(2,3,1)
plt.title("Pressione",fontweight='bold')
plt.errorbar(x,pres[1][60:120],yerr=pres[3][60:120],ecolor='r')
plt.xlabel("Blocks")
plt.ylabel("Pressione")
plt.grid(True)

plt.subplot(2,3,2)
plt.title("Temperatura",fontweight='bold')
plt.errorbar(x,temp[1][60:120],yerr=temp[3][60:120],ecolor='r')
plt.axhline(1.1,color='g',label="$T^*$")
plt.xlabel("Blocks")
plt.ylabel("$T^*$")
plt.legend()
plt.grid(True)

plt.subplot(2,3,3)
plt.title("Energia potenziale",fontweight='bold')
plt.errorbar(x,epot[1][60:120],yerr=epot[3][60:120],ecolor='r')
plt.xlabel("Blocks")
plt.ylabel("$U^*/N$")
plt.grid(True)

plt.subplot(2,3,4)
plt.title("Energia cinetica",fontweight='bold')
plt.errorbar(x,ekin[1][60:120],yerr=ekin[3][60:120],ecolor='r')
plt.xlabel("Blocks")
plt.ylabel("$K^*/N$")
plt.grid(True)

plt.subplot(2,3,5)
plt.title("Energia totale",fontweight='bold')
plt.errorbar(x,etot[1][60:120],yerr=etot[3][60:120],ecolor='r')
plt.xlabel("Blocks")
plt.ylabel("$E^*/N$")
plt.grid(True)

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Grafici solido

# %%
plt.figure(figsize=(20,12))

plt.suptitle("SOLIDO",fontsize=26,fontweight='bold')

plt.subplot(2,3,1)
plt.title("Pressione",fontweight='bold')
plt.errorbar(x,pres[1][120:180],yerr=pres[3][120:180],ecolor='r')
plt.xlabel("Blocks")
plt.ylabel("Pressione")
plt.grid(True)

plt.subplot(2,3,2)
plt.title("Temperatura",fontweight='bold')
plt.errorbar(x,temp[1][120:180],yerr=temp[3][120:180],ecolor='r')
plt.axhline(0.8,color='g',label="$T^*$")
plt.xlabel("Blocks")
plt.ylabel("$T^*$")
plt.legend()
plt.grid(True)
plt.grid(True)

plt.subplot(2,3,3)
plt.title("Energia potenziale",fontweight='bold')
plt.errorbar(x,epot[1][120:180],yerr=epot[3][120:180],ecolor='r')
plt.xlabel("Blocks")
plt.ylabel("$U^*/N$")
plt.grid(True)

plt.subplot(2,3,4)
plt.title("Energia cinetica",fontweight='bold')
plt.errorbar(x,ekin[1][120:180],yerr=ekin[3][120:180],ecolor='r')
plt.xlabel("Blocks")
plt.ylabel("$K^*/N$")
plt.grid(True)

plt.subplot(2,3,5)
plt.title("Energia totale",fontweight='bold')
plt.errorbar(x,etot[1][120:180],yerr=etot[3][120:180],ecolor='r')
plt.xlabel("Blocks")
plt.ylabel("$E^*/N$")
plt.grid(True)

plt.tight_layout()

plt.show()
